# %%
import pandas as pd
import matplotlib.font_manager

fonts = matplotlib.font_manager.findSystemFonts()

l = []

for f in fonts:

    try:

        font =matplotlib.font_manager.FontProperties(fname=f)

        #print(font.get_family())

        l.append((f, font.get_name(), font.get_family(), font.get_weight()))

    except:

        pass

df = pd.DataFrame(l, columns=['path', 'name', 'family', 'weight'])

df
# Out:
# Missing colon in file PosixPath('/app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/matplotlibrc'), line 405 (' use Unicode for the minus symbol rather than hyphen.  See')
#                                                  path              name  \
# 0     /app/data/appuser/anaconda3/fonts/Ubuntu-LI.ttf            Ubuntu
# 1   /usr/share/fonts/dejavu/DejaVuSans-ExtraLight.ttf       DejaVu Sans
# 2   /usr/share/fonts/dejavu/DejaVuSans-BoldOblique...       DejaVu Sans
# 3   /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
# 4   /usr/share/fonts/dejavu/DejaVuSansCondensed-Bo...       DejaVu Sans
# 5   /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
# 6   /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
# 7   /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
# 8   /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
# 9   /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
# 10  /app/data/appuser/anaconda3/fonts/UbuntuMono-B...       Ubuntu Mono
# 11  /usr/share/fonts/dejavu/DejaVuSansCondensed-Bo...       DejaVu Sans
# 12     /app/data/appuser/anaconda3/fonts/Ubuntu-M.ttf            Ubuntu
# 13  /app/data/appuser/anaconda3/fonts/Inconsolata-...       Inconsolata
# 14  /app/data/appuser/anaconda3/fonts/UbuntuMono-R...       Ubuntu Mono
# 15  /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
# 16  /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
# 17             /usr/share/fonts/dejavu/DejaVuSans.ttf       DejaVu Sans
# 18     /app/data/appuser/anaconda3/fonts/Ubuntu-R.ttf            Ubuntu
# 19  /app/data/appuser/anaconda3/fonts/UbuntuMono-R...       Ubuntu Mono
# 20  /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
# 21    /app/data/appuser/anaconda3/fonts/Ubuntu-MI.ttf            Ubuntu
# 22     /app/data/appuser/anaconda3/fonts/Ubuntu-L.ttf            Ubuntu
# 23  /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
# 24   /app/data/appuser/anaconda3/fonts/DejaVuSans.ttf       DejaVu Sans
# 25     /app/data/appuser/anaconda3/fonts/Ubuntu-B.ttf            Ubuntu
# 26  /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
# 27    /app/data/appuser/anaconda3/fonts/Ubuntu-Th.ttf            Ubuntu
# 28    /app/data/appuser/anaconda3/fonts/Ubuntu-BI.ttf            Ubuntu
# 29  /app/data/appuser/anaconda3/fonts/UbuntuMono-B...       Ubuntu Mono
# 30        /usr/share/fonts/dejavu/DejaVuSans-Bold.ttf       DejaVu Sans
# 31     /app/data/appuser/anaconda3/fonts/Ubuntu-C.ttf  Ubuntu Condensed
# 32     /usr/share/fonts/dejavu/DejaVuSans-Oblique.ttf       DejaVu Sans
# 33  /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
# 34  /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
# 35  /app/data/appuser/anaconda3/fonts/Inconsolata-...       Inconsolata
# 36    /app/data/appuser/anaconda3/fonts/Ubuntu-RI.ttf            Ubuntu
# 37    /usr/share/fonts/dejavu/DejaVuSansCondensed.ttf       DejaVu Sans
# 38  /usr/share/fonts/dejavu/DejaVuSansCondensed-Ob...       DejaVu Sans
# 39  /app/data/appuser/anaconda3/fonts/SourceCodePr...   Source Code Pro
#
#           family  weight
# 0   [sans-serif]  normal
# 1   [sans-serif]  normal
# 2   [sans-serif]  normal
# 3   [sans-serif]  normal
# 4   [sans-serif]  normal
# 5   [sans-serif]  normal
# 6   [sans-serif]  normal
# 7   [sans-serif]  normal
# 8   [sans-serif]  normal
# 9   [sans-serif]  normal
# 10  [sans-serif]  normal
# 11  [sans-serif]  normal
# 12  [sans-serif]  normal
# 13  [sans-serif]  normal
# 14  [sans-serif]  normal
# 15  [sans-serif]  normal
# 16  [sans-serif]  normal
# 17  [sans-serif]  normal
# 18  [sans-serif]  normal
# 19  [sans-serif]  normal
# 20  [sans-serif]  normal
# 21  [sans-serif]  normal
# 22  [sans-serif]  normal
# 23  [sans-serif]  normal
# 24  [sans-serif]  normal
# 25  [sans-serif]  normal
# 26  [sans-serif]  normal
# 27  [sans-serif]  normal
# 28  [sans-serif]  normal
# 29  [sans-serif]  normal
# 30  [sans-serif]  normal
# 31  [sans-serif]  normal
# 32  [sans-serif]  normal
# 33  [sans-serif]  normal
# 34  [sans-serif]  normal
# 35  [sans-serif]  normal
# 36  [sans-serif]  normal
# 37  [sans-serif]  normal
# 38  [sans-serif]  normal
# 39  [sans-serif]  normal

# %%
import matplotlib
print(matplotlib.__file__)
# Out:
# /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py

# %%
matplotlib.get_cachedir()
# Out:
# '/app/data/appuser/.cache/matplotlib'

# %%
matplotlib.matplotlib_fname()
# Out:
# '/app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
from matplotlib import font_manager
for font in font_manager.fontManager.ttflist:
    print(font.name, '      ', font.fname)
# Out:
# cmss10        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf
# STIXSizeFiveSym        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf
# STIXSizeTwoSym        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf
# DejaVu Sans        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf
# STIXSizeThreeSym        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf
# STIXSizeFourSym        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf
# cmb10        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
# DejaVu Sans Mono        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf
# STIXNonUnicode        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf
# STIXSizeTwoSym        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf
# DejaVu Sans        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf
# cmr10        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf
# cmmi10        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf
# STIXGeneral        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf
# STIXSizeOneSym        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf
# DejaVu Sans Mono        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf
# STIXNonUnicode        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf
# DejaVu Sans Mono        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf
# cmtt10        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf
# cmex10        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf
# DejaVu Serif        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf
# STIXSizeFourSym        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf
# DejaVu Serif        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf
# STIXNonUnicode        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf
# STIXSizeThreeSym        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf
# DejaVu Serif Display        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf
# SimHei        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/SimHei.ttf
# STIXGeneral        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf
# STIXSizeOneSym        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf
# DejaVu Sans Mono        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf
# DejaVu Serif        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf
# DejaVu Sans        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf
# STIXGeneral        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf
# DejaVu Sans Display        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf
# DejaVu Serif        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf
# DejaVu Sans        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf
# cmsy10        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf
# STIXNonUnicode        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf
# STIXGeneral        /app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-Medium.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-BoldIt.ttf
# Ubuntu Mono        /app/data/appuser/anaconda3/fonts/UbuntuMono-R.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-It.ttf
# Ubuntu        /app/data/appuser/anaconda3/fonts/Ubuntu-Th.ttf
# Ubuntu Condensed        /app/data/appuser/anaconda3/fonts/Ubuntu-C.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-Bold.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-MediumIt.ttf
# DejaVu Sans        /usr/share/fonts/dejavu/DejaVuSans.ttf
# DejaVu Sans        /usr/share/fonts/dejavu/DejaVuSansCondensed.ttf
# Ubuntu        /app/data/appuser/anaconda3/fonts/Ubuntu-L.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-Black.ttf
# Inconsolata        /app/data/appuser/anaconda3/fonts/Inconsolata-Bold.ttf
# Ubuntu        /app/data/appuser/anaconda3/fonts/Ubuntu-LI.ttf
# DejaVu Sans        /usr/share/fonts/dejavu/DejaVuSans-ExtraLight.ttf
# DejaVu Sans        /usr/share/fonts/dejavu/DejaVuSans-BoldOblique.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-ExtraLightIt.ttf
# DejaVu Sans        /app/data/appuser/anaconda3/fonts/DejaVuSans.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-Regular.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-BlackIt.ttf
# Ubuntu        /app/data/appuser/anaconda3/fonts/Ubuntu-MI.ttf
# Inconsolata        /app/data/appuser/anaconda3/fonts/Inconsolata-Regular.ttf
# DejaVu Sans        /usr/share/fonts/dejavu/DejaVuSansCondensed-Bold.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-SemiboldIt.ttf
# DejaVu Sans        /usr/share/fonts/dejavu/DejaVuSansCondensed-Oblique.ttf
# Ubuntu        /app/data/appuser/anaconda3/fonts/Ubuntu-B.ttf
# Ubuntu        /app/data/appuser/anaconda3/fonts/Ubuntu-BI.ttf
# Ubuntu Mono        /app/data/appuser/anaconda3/fonts/UbuntuMono-BI.ttf
# Ubuntu Mono        /app/data/appuser/anaconda3/fonts/UbuntuMono-RI.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-ExtraLight.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-Semibold.ttf
# DejaVu Sans        /usr/share/fonts/dejavu/DejaVuSansCondensed-BoldOblique.ttf
# Ubuntu        /app/data/appuser/anaconda3/fonts/Ubuntu-RI.ttf
# DejaVu Sans        /usr/share/fonts/dejavu/DejaVuSans-Oblique.ttf
# Ubuntu        /app/data/appuser/anaconda3/fonts/Ubuntu-M.ttf
# Ubuntu Mono        /app/data/appuser/anaconda3/fonts/UbuntuMono-B.ttf
# DejaVu Sans        /usr/share/fonts/dejavu/DejaVuSans-Bold.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-Light.ttf
# Ubuntu        /app/data/appuser/anaconda3/fonts/Ubuntu-R.ttf
# Source Code Pro        /app/data/appuser/anaconda3/fonts/SourceCodePro-LightIt.ttf

# %%
from matplotlib.font_manager import _rebuild
_rebuild()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_1464/2521548551.py in <module>
# ----> 1 from matplotlib.font_manager import _rebuild
#       2 _rebuild()
#
# ImportError: cannot import name '_rebuild' from 'matplotlib.font_manager' (/app/data/appuser/anaconda3/lib/python3.9/site-packages/matplotlib/font_manager.py)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['Simhei'] # 指定默认字体 Simsun为宋体，不指定为新罗马字体Times New Roman

plt.plot(1,1)
plt.title('中文字体')
# Out:
# Text(0.5, 1.0, '中文字体')
